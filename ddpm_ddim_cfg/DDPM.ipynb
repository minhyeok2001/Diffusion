# %% [markdown]
# <a href="https://colab.research.google.com/github/minhyeok2001/Diffusion/blob/main/ddpm_ddim_cfg/DDPM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/minhyeok2001/Diffusion
# Out:
# Cloning into 'Diffusion'...
# remote: Enumerating objects: 558, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 558 (delta 75), reused 49 (delta 38), pack-reused 460 (from 1)
# Receiving objects: 100% (558/558), 80.45 MiB | 16.75 MiB/s, done.
# Resolving deltas: 100% (327/327), done.

# %%
from google.colab import files
import os
uploaded = files.upload()
os.makedirs("/root/.config/kaggle", exist_ok=True)
os.rename(list(uploaded)[0], "/root/.config/kaggle/kaggle.json")
# Out:
#      <input type="file" id="files-4cc1f037-0551-4827-aad4-b742a035402f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4cc1f037-0551-4827-aad4-b742a035402f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ls
# Out:
# Diffusion/  drive/  sample_data/

# %%
cd Diffusion
# Out:
# /content/Diffusion

# %%
# !python -m ddpm_ddim_cfg.train --batch_size 16 --epoch 200 --lr 0.00005
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/andrewmvd/animal-faces
# ...
#  97% 676M/696M [00:00<00:00, 1.77GB/s]
# 100% 696M/696M [00:00<00:00, 1.77GB/s]
# Download Complete !!
# get_data.py executed...
# dataloader.py executed...
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: mhroh01 (mhroh01-ajou-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run xluiuzxz (0.2s)
# wandb: ⣽ setting up run xluiuzxz (0.2s)
# wandb: ⣾ setting up run xluiuzxz (0.2s)
# wandb: Tracking run with wandb version 0.22.2
# ...

# %%
cd checkpoints/val_samples/

# %%
from IPython.display import Image, display

for i in range(0,200,20):
  filename = f'iter_{i}_timeline.png'
  print(f"==========={i}============")
  display(Image(filename=filename))

# %%
cd ../../

# %%
import shutil

src_path = "checkpoints/Diffusion.pth"

dst_path = "/content/drive/MyDrive/Diffusion.pth"

shutil.copy(src_path, dst_path)

print("저장 완료:", dst_path)

# %%
from google.colab import files
files.download("checkpoints/Diffusion.pth")

# %%
cd ..

# %%
# !python fid_score/measure_fid.py checkpoints/val_samples/real checkpoints/val_samples/gen
