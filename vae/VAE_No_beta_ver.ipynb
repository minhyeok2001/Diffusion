# %% [markdown]
# <a href="https://colab.research.google.com/github/minhyeok2001/Diffusion/blob/main/vae/VAE_No_beta_ver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/minhyeok2001/Diffusion
# Out:
# Cloning into 'Diffusion'...
# remote: Enumerating objects: 350, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 350 (delta 72), reused 50 (delta 24), pack-reused 233 (from 1)
# Receiving objects: 100% (350/350), 78.99 MiB | 50.17 MiB/s, done.
# Resolving deltas: 100% (184/184), done.

# %%
from google.colab import files
import os
uploaded = files.upload()
os.makedirs("/root/.config/kaggle", exist_ok=True)
os.rename(list(uploaded)[0], "/root/.config/kaggle/kaggle.json")
# Out:
#      <input type="file" id="files-39fd9527-bf75-4723-a9f0-a2529e4aad5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39fd9527-bf75-4723-a9f0-a2529e4aad5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ls
# Out:
# Diffusion/  sample_data/

# %%
cd Diffusion
# Out:
# /content/Diffusion

# %%
# !python -m vae.train --batch_size 32 --lr 0.0001 --epoch 150 --beta 1.0
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/andrewmvd/animal-faces
# ...
#  96% 667M/696M [00:00<00:00, 1.73GB/s]
# 100% 696M/696M [00:00<00:00, 1.73GB/s]
# Download Complete !!
# get_data.py executed...
# dataloader.py executed...
# model params :  69897995
# model params :  69897995
# 100% 149/149 [01:26<00:00,  1.73it/s]
# Epoch [1/150] | Train Loss: 0.186794
# 10it [00:00, 11.05it/s]
# Epoch [1/150] | Val Loss: 0.178621
# 100% 149/149 [01:24<00:00,  1.76it/s]
# Epoch [2/150] | Train Loss: 0.147569
# 10it [00:00, 11.05it/s]
# Epoch [2/150] | Val Loss: 0.140170
# 100% 149/149 [01:24<00:00,  1.76it/s]
# Epoch [3/150] | Train Loss: 0.142801
# 10it [00:00, 11.16it/s]
# Epoch [3/150] | Val Loss: 0.150924
# 100% 149/149 [01:24<00:00,  1.76it/s]
# Epoch [4/150] | Train Loss: 0.141971
# 10it [00:00, 11.29it/s]
# Epoch [4/150] | Val Loss: 0.138309
# 100% 149/149 [01:24<00:00,  1.76it/s]
# Epoch [5/150] | Train Loss: 0.139461
# 10it [00:00, 11.26it/s]
# Epoch [5/150] | Val Loss: 0.144210
# ...

# %%
cd checkpoints/val_samples/
# Out:
# /content/Diffusion/checkpoints/val_samples

# %%
ls
# Out:
# gen/                             reconstructed_img_epoch_31.png
# real/                            reconstructed_img_epoch_32.png
# reconstructed_img_epoch_100.png  reconstructed_img_epoch_33.png
# reconstructed_img_epoch_101.png  reconstructed_img_epoch_34.png
# reconstructed_img_epoch_102.png  reconstructed_img_epoch_35.png
# reconstructed_img_epoch_103.png  reconstructed_img_epoch_36.png
# reconstructed_img_epoch_104.png  reconstructed_img_epoch_37.png
# reconstructed_img_epoch_105.png  reconstructed_img_epoch_38.png
# reconstructed_img_epoch_106.png  reconstructed_img_epoch_39.png
# reconstructed_img_epoch_107.png  reconstructed_img_epoch_3.png
# reconstructed_img_epoch_108.png  reconstructed_img_epoch_40.png
# reconstructed_img_epoch_109.png  reconstructed_img_epoch_41.png
# reconstructed_img_epoch_10.png   reconstructed_img_epoch_42.png
# reconstructed_img_epoch_110.png  reconstructed_img_epoch_43.png
# reconstructed_img_epoch_111.png  reconstructed_img_epoch_44.png
# ...

# %%
from IPython.display import Image, display

for i in range(150,1,-20):
  filename = f'reconstructed_img_epoch_{i}.png'
  display(Image(filename=filename))

# %%
cd ../../
# Out:
# /content/Diffusion

# %%
# !python fid_score/measure_fid.py checkpoints/val_samples/real checkpoints/val_samples/gen
# Out:
# Calculating FID given paths checkpoints/val_samples/real and checkpoints/val_samples/gen...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# 100% 5/5 [00:00<00:00,  5.02it/s]
# ...

# %%
from google.colab import files
files.download("checkpoints/Diffusion.pth")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3670668828.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download("checkpoints/Diffusion.pth")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: checkpoints/Diffusion.pth
